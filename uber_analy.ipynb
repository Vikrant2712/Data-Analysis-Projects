# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt

# %%
import os

# %%
os.listdir(r"./Onedrive/Desktop/Uber/Datasets")
# Out:
# ['other-American_B01362.csv',
#  'other-Carmel_B00256.csv',
#  'other-Dial7_B00887.csv',
#  'other-Diplo_B01196.csv',
#  'other-Federal_02216.csv',
#  'other-FHV-services_jan-aug-2015.csv',
#  'other-Firstclass_B01536.csv',
#  'other-Highclass_B01717.csv',
#  'other-Lyft_B02510.csv',
#  'other-Prestige_B01338.csv',
#  'other-Skyline_B00111.csv',
#  'Uber-Jan-Feb-FOIL.csv',
#  'uber-raw-data-apr14.csv',
#  'uber-raw-data-aug14.csv',
#  'uber-raw-data-janjune-15.csv',
#  'uber-raw-data-janjune-15_sample.csv',
#  'uber-raw-data-jul14.csv',
#  'uber-raw-data-jun14.csv',
#  'uber-raw-data-may14.csv',
#  'uber-raw-data-sep14.csv']

# %%
uber_15=pd.read_csv(r"./Onedrive/Desktop/Uber/Datasets/uber-raw-data-janjune-15_sample.csv")

# %%
uber_15.shape
# Out:
# (100000, 4)

# %%
uber_15.duplicated()
# Out:
# 0        False
# 1        False
# 2        False
# 3        False
# 4        False
#          ...
# 99995    False
# 99996    False
# 99997    False
# 99998    False
# 99999    False
# Length: 100000, dtype: bool

# %%
uber_15.duplicated().sum()
# Out:
# 54

# %%
uber_15.drop_duplicates(inplace=True)

# %%
uber_15.duplicated().sum()
# Out:
# 0

# %%
uber_15.shape
# Out:
# (99946, 4)

# %%
uber_15.dtypes
# Out:
# Dispatching_base_num    object
# Pickup_date             object
# Affiliated_base_num     object
# locationID               int64
# dtype: object

# %%
uber_15.isnull()
# Out:
#        Dispatching_base_num  Pickup_date  Affiliated_base_num  locationID
# 0                     False        False                False       False
# 1                     False        False                False       False
# 2                     False        False                False       False
# 3                     False        False                False       False
# 4                     False        False                False       False
# ...                     ...          ...                  ...         ...
# 99995                 False        False                False       False
# 99996                 False        False                False       False
# 99997                 False        False                False       False
# 99998                 False        False                False       False
# 99999                 False        False                False       False
#
# [99946 rows x 4 columns]

# %%
uber_15.isnull().sum()
# Out:
# Dispatching_base_num       0
# Pickup_date                0
# Affiliated_base_num     1116
# locationID                 0
# dtype: int64

# %%
uber_15["Pickup_date"][0]
# Out:
# '2015-05-02 21:43:00'

# %%
type(uber_15["Pickup_date"][0])
# Out:
# str

# %%
 uber_15["Pickup_date"] = pd.to_datetime(uber_15["Pickup_date"])

# %%
uber_15["Pickup_date"].dtype
# Out:
# dtype('<M8[ns]')

# %%
uber_15["Pickup_date"][0]
# Out:
# Timestamp('2015-05-02 21:43:00')

# %%
type(uber_15["Pickup_date"][0])
# Out:
# pandas._libs.tslibs.timestamps.Timestamp

# %%
uber_15.dtypes
# Out:
# Dispatching_base_num            object
# Pickup_date             datetime64[ns]
# Affiliated_base_num             object
# locationID                       int64
# dtype: object

# %%
uber_15
# Out:
#       Dispatching_base_num         Pickup_date Affiliated_base_num  locationID
# 0                   B02617 2015-05-02 21:43:00              B02764         237
# 1                   B02682 2015-01-20 19:52:59              B02682         231
# 2                   B02617 2015-03-19 20:26:00              B02617         161
# 3                   B02764 2015-04-10 17:38:00              B02764         107
# 4                   B02764 2015-03-23 07:03:00              B00111         140
# ...                    ...                 ...                 ...         ...
# 99995               B02764 2015-04-13 16:12:00              B02764         234
# 99996               B02764 2015-03-06 21:32:00              B02764          24
# 99997               B02598 2015-03-19 19:56:00              B02598          17
# 99998               B02682 2015-05-02 16:02:00              B02682          68
# 99999               B02764 2015-06-24 16:04:00              B02764         125
#
# ...

# %%
uber_15['Pickup_date'].dt.month
# Out:
# 0        5
# 1        1
# 2        3
# 3        4
# 4        3
#         ..
# 99995    4
# 99996    3
# 99997    3
# 99998    5
# 99999    6
# Name: Pickup_date, Length: 99946, dtype: int32

# %%
uber_15['month'] = uber_15['Pickup_date'].dt.month_name()

# %%
uber_15['month']
# Out:
# 0            May
# 1        January
# 2          March
# 3          April
# 4          March
#           ...
# 99995      April
# 99996      March
# 99997      March
# 99998        May
# 99999       June
# Name: month, Length: 99946, dtype: object

# %%
uber_15['month'].value_counts()
# Out:
# month
# June        19620
# May         18660
# April       15982
# March       15969
# February    15896
# January     13819
# Name: count, dtype: int64

# %%
uber_15['month'].value_counts().plot()
# Out:
# <Axes: xlabel='month'>

# %%
uber_15['month'].value_counts().plot(kind='bar')
# Out:
# <Axes: xlabel='month'>

# %%
uber_15['Pickup_date'].dt.day_name()
# Out:
# 0         Saturday
# 1          Tuesday
# 2         Thursday
# 3           Friday
# 4           Monday
#            ...
# 99995       Monday
# 99996       Friday
# 99997     Thursday
# 99998     Saturday
# 99999    Wednesday
# Name: Pickup_date, Length: 99946, dtype: object

# %%
uber_15['weekday'] = uber_15['Pickup_date'].dt.day_name()
uber_15['day'] =  uber_15['Pickup_date'].dt.day
uber_15['hour'] =  uber_15['Pickup_date'].dt.hour
uber_15['minute'] =  uber_15['Pickup_date'].dt.minute

# %%
uber_15.head(4)
# Out:
#   Dispatching_base_num         Pickup_date Affiliated_base_num  locationID  \
# 0               B02617 2015-05-02 21:43:00              B02764         237
# 1               B02682 2015-01-20 19:52:59              B02682         231
# 2               B02617 2015-03-19 20:26:00              B02617         161
# 3               B02764 2015-04-10 17:38:00              B02764         107
#
#      month   weekday  day  hour  minute
# 0      May  Saturday    2    21      43
# 1  January   Tuesday   20    19      52
# 2    March  Thursday   19    20      26
# 3    April    Friday   10    17      38

# %%
pivot = pd.crosstab(index=uber_15['month'] , columns=uber_15['weekday'])

# %%
pivot
# Out:
# weekday   Friday  Monday  Saturday  Sunday  Thursday  Tuesday  Wednesday
# month
# April       2365    1833      2508    2052      2823     1880       2521
# February    2655    1970      2550    2183      2396     2129       2013
# January     2508    1353      2745    1651      2378     1444       1740
# June        2793    2848      3037    2485      2767     3187       2503
# March       2465    2115      2522    2379      2093     2388       2007
# May         3262    1865      3519    2944      2627     2115       2328

# %%
pivot.plot(kind='bar' , figsize=(8,6))
# Out:
# <Axes: xlabel='month'>

# %%
summary = uber_15.groupby(['weekday', 'hour'], as_index = False).size()

# %%
summary
# Out:
#        weekday  hour  size
# 0       Friday     0   581
# 1       Friday     1   333
# 2       Friday     2   197
# 3       Friday     3   138
# 4       Friday     4   161
# ..         ...   ...   ...
# 163  Wednesday    19  1044
# 164  Wednesday    20   897
# 165  Wednesday    21   949
# 166  Wednesday    22   900
# 167  Wednesday    23   669
#
# [168 rows x 3 columns]

# %%
plt.figure(figsize= (8,6))
sns.pointplot(x="hour" , y = "size" , hue = "weekday" , data = summary)
# Out:
# <Axes: xlabel='hour', ylabel='size'>

# %%
uber_15.columns
# Out:
# Index(['Dispatching_base_num', 'Pickup_date', 'Affiliated_base_num',
#        'locationID', 'month', 'weekday', 'day', 'hour', 'minute'],
#       dtype='object')

# %%
os.listdir(r"./Onedrive/Desktop/Uber/Datasets")
# Out:
# ['other-American_B01362.csv',
#  'other-Carmel_B00256.csv',
#  'other-Dial7_B00887.csv',
#  'other-Diplo_B01196.csv',
#  'other-Federal_02216.csv',
#  'other-FHV-services_jan-aug-2015.csv',
#  'other-Firstclass_B01536.csv',
#  'other-Highclass_B01717.csv',
#  'other-Lyft_B02510.csv',
#  'other-Prestige_B01338.csv',
#  'other-Skyline_B00111.csv',
#  'Uber-Jan-Feb-FOIL.csv',
#  'uber-raw-data-apr14.csv',
#  'uber-raw-data-aug14.csv',
#  'uber-raw-data-janjune-15.csv',
#  'uber-raw-data-janjune-15_sample.csv',
#  'uber-raw-data-jul14.csv',
#  'uber-raw-data-jun14.csv',
#  'uber-raw-data-may14.csv',
#  'uber-raw-data-sep14.csv']

# %%
uber_foil = pd.read_csv(r"./Onedrive/Desktop/Uber/Datasets/Uber-Jan-Feb-FOIL.csv")

# %%
uber_foil
# Out:
#     dispatching_base_number       date  active_vehicles  trips
# 0                    B02512   1/1/2015              190   1132
# 1                    B02765   1/1/2015              225   1765
# 2                    B02764   1/1/2015             3427  29421
# 3                    B02682   1/1/2015              945   7679
# 4                    B02617   1/1/2015             1228   9537
# ..                      ...        ...              ...    ...
# 349                  B02764  2/28/2015             3952  39812
# 350                  B02617  2/28/2015             1372  14022
# 351                  B02682  2/28/2015             1386  14472
# 352                  B02512  2/28/2015              230   1803
# 353                  B02765  2/28/2015              747   7753
#
# [354 rows x 4 columns]

# %%
uber_foil.shape
# Out:
# (354, 4)

# %%
# !pip install chart_studio
# !pip install plotly

# %%
import chart_studio.plotly as py
import plotly.graph_objs as go
import plotly.express as px

from plotly.offline import download_plotlyjs , init_notebook_mode , plot , iplot

# %%
init_notebook_mode(connected=True)
# Out:
#         <script type="text/javascript">
#         window.PlotlyConfig = {MathJaxConfig: 'local'};
#         if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}
#         if (typeof require !== 'undefined') {
#         require.undef("plotly");
#         requirejs.config({
#             paths: {
#                 'plotly': ['https://cdn.plot.ly/plotly-2.35.2.min']
#             }
#         });
#         require(['plotly'], function(Plotly) {
#             window._Plotly = Plotly;
#         });
#         }
#         </script>

# %%
uber_foil.columns
# Out:
# Index(['dispatching_base_number', 'date', 'active_vehicles', 'trips'], dtype='object')

# %%
px.box(x='dispatching_base_number' , y='active_vehicles' , data_frame=uber_foil)
# Out:
# <div>                            <div id="06dff663-ee85-454d-bb17-6aba14a5523a" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("06dff663-ee85-454d-bb17-6aba14a5523a")) {                    Plotly.newPlot(                        "06dff663-ee85-454d-bb17-6aba14a5523a",                        [{"alignmentgroup":"True","hovertemplate":"dispatching_base_number=%{x}\u003cbr\u003eactive_vehicles=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"","marker":{"color":"#636efa"},"name":"","notched":false,"offsetgroup":"","orientation":"v","showlegend":false,"x":["B02512","B02765","B02764","B02682","B02617","B02598","B02598","B02617","B02512","B02682","B02765","B02764","B02765","B02617","B02598","B02682","B02512","B02764","B02512","B02682","B02598","
# ...

# %%
###if you need distribution + S-summary stats of data , its good to go with violinplot
px.violin(x='dispatching_base_number' , y='active_vehicles' , data_frame=uber_foil)
# Out:
# <div>                            <div id="85bf4e23-8fd5-4b8a-8b60-a5c44578ae07" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("85bf4e23-8fd5-4b8a-8b60-a5c44578ae07")) {                    Plotly.newPlot(                        "85bf4e23-8fd5-4b8a-8b60-a5c44578ae07",                        [{"alignmentgroup":"True","box":{"visible":false},"hovertemplate":"dispatching_base_number=%{x}\u003cbr\u003eactive_vehicles=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"","marker":{"color":"#636efa"},"name":"","offsetgroup":"","orientation":"v","scalegroup":"True","showlegend":false,"x":["B02512","B02765","B02764","B02682","B02617","B02598","B02598","B02617","B02512","B02682","B02765","B02764","B02765","B02617","B02598","B02682","B02512","B02764",
# ...

# %%
files = os.listdir(r"./Onedrive/Desktop/Uber/Datasets")[-8:]

# %%
files.remove('uber-raw-data-janjune-15_sample.csv')

# %%
files
# Out:
# ['uber-raw-data-apr14.csv',
#  'uber-raw-data-aug14.csv',
#  'uber-raw-data-janjune-15.csv',
#  'uber-raw-data-jul14.csv',
#  'uber-raw-data-jun14.csv',
#  'uber-raw-data-may14.csv',
#  'uber-raw-data-sep14.csv']

# %%
final = pd.DataFrame()

path = r"./Onedrive/Desktop/Uber/Datasets"

for file in files:
    current_df = pd.read_csv(path+'/'+file)
    final = pd.concat([current_df , final])

# %%
final.shape
# Out:
# (18804806, 8)

# %%
final.duplicated().sum()
# Out:
# 980806

# %%
final.drop_duplicates(inplace=True)

# %%
final.shape
# Out:
# (17824000, 8)

# %%
final.head(3)
# Out:
#           Date/Time      Lat      Lon    Base Dispatching_base_num  \
# 0  9/1/2014 0:01:00  40.2201 -74.0021  B02512                  NaN
# 1  9/1/2014 0:01:00  40.7500 -74.0027  B02512                  NaN
# 2  9/1/2014 0:03:00  40.7559 -73.9864  B02512                  NaN
#
#   Pickup_date Affiliated_base_num  locationID
# 0         NaN                 NaN         NaN
# 1         NaN                 NaN         NaN
# 2         NaN                 NaN         NaN

# %%
........................................................................
.0
